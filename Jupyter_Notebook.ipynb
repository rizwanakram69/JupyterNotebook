# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Muhammad Rizwan Akram</b>
#
# Data Scientist

# %% [markdown]
# <i>I am interested in Data Science because I love to add my contribution in company growing using my data science skills.</i>

# %% [markdown]
# ### below code should take input name from user and print (Welcome, name entered by user)

# %%
name = input("Enter your name: ")
print('Welcome, ', name)
# Out:
# Enter your name: Muhammad Rizwan Akram
# Welcome,  Muhammad Rizwan Akram

# %% [markdown]
# <b> Bullet list</b>
# - Apple
# - Mango
# - Banana
#
# <b> Numbered list </b>
# 1. Honda
# 2. Toyota
# 3. Suzuki
#
# <b> Hyperlinks</b><br>
# <a href="www.google.com">Google</a>
# <a href="www.facebook.com">Facebook</a>
# <a href="www.twitter.com">Twitter</a>
